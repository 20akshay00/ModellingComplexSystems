# %%
using Plots

# %%
s = []
i = []
r = []
t = []

push!(s,[36866, 33858, 30978, 28226, 25602, 23130, 20746, 18546, 16386, 14402, 12546, 10866, 9298, 7754, 6522])

push!(i,[1190, 2362, 3514, 4646, 5758, 6874, 7942, 9022, 10006, 11018, 12010, 13078, 14062, 14914, 15958])

push!(r,[2778, 5514, 8206, 10854, 13458, 16042, 18554, 21054, 23434, 25818, 28158, 30550, 32834, 34962, 37258])

push!(t,[209, 109, 76, 59, 49, 43, 38, 34, 32, 29, 28, 26, 25, 24, 23])

()
# Out:
# ()

# %%
push!(s,[33888, 28416, 23200, 18769, 14641, 11881, 8416, 6561, 3424, 1681, 928, 625, 1, 1, 0])

push!(i,[2352, 4584, 6840, 8688, 10759, 12600, 14784, 16224, 18576, 20119, 21912, 22608, 22839, 26040, 25359])

push!(r,[4684, 9096, 13476, 17343, 21299, 24504, 28476, 31136, 35244, 38199, 40964, 42096, 44835, 47544, 49179])

push!(t,[109, 59, 43, 34, 29, 26, 24, 22, 21, 19, 19, 18, 17, 17, 16])
# Out:
# 2-element Array{Any,1}:
#  [209, 109, 76, 59, 49, 43, 38, 34, 32, 29, 28, 26, 25, 24, 23]
#  [109, 59, 43, 34, 29, 26, 24, 22, 21, 19, 19, 18, 17, 17, 16]

# %%
push!(s,[36866, 33858, 30986, 28226, 25602, 23114, 20758, 18514, 16418, 14402, 12586, 10850, 9234, 7794, 6422])

push!(i,[1190, 2358, 3518, 4654, 5778, 6830, 7958, 8974, 10118, 11158, 12190, 13070, 13970, 15126, 15818])

push!(r,[2778, 5510, 8210, 10862, 13478, 15998, 18570, 21006, 23546, 25958, 28338, 30542, 32742, 35174, 37118])

push!(t,[209, 109, 77, 59, 49, 43, 39, 35, 33, 29, 29, 27, 25, 25, 23])
# Out:
# 3-element Array{Any,1}:
#  [209, 109, 76, 59, 49, 43, 38, 34, 32, 29, 28, 26, 25, 24, 23]
#  [109, 59, 43, 34, 29, 26, 24, 22, 21, 19, 19, 18, 17, 17, 16]
#  [209, 109, 77, 59, 49, 43, 39, 35, 33, 29, 29, 27, 25, 25, 23]

# %%
x = 1:15
p1 = plot(x, s)
p2 = plot(x, i)
p3 = plot(x, r)
p4 = plot(x, t)

plot(p1, p2, p3, p4, size = (900, 500), lw = 2)

# %%
s1 = []
i1 = []
r1 = []
t1 = []
# Out:
# 0-element Array{Any,1}

# %%
push!(s1, [36866, 33858, 30978, 28226, 25602, 23130, 20746, 18546, 16386, 14402, 12546, 10866, 9298, 7754, 6522])

push!(i1, [1582, 3134, 4654, 6142, 7598, 8998, 10406, 11726, 13102, 14398, 15662, 16846, 18014, 19254, 20278])

push!(r1, [2386, 4750, 7090, 9406, 11698, 13942, 16202, 18382, 20626, 22798, 24946, 27022, 29090, 31238, 33178])

push!(t1, [209, 109, 76, 59, 49, 43, 38, 34, 32, 29, 28, 26, 25, 24, 23])
# Out:
# 1-element Array{Any,1}:
#  [209, 109, 76, 59, 49, 43, 38, 34, 32, 29, 28, 26, 25, 24, 23]

# %%
pp1 = plot(x, [s[1], s1])
pp2 = plot(x, [i[1], i1])
pp3 = plot(x, [r[1], r1])
pp4 = plot(x, [t[1], t1])

plot(pp1, pp2, pp3, pp4, lw = 2, size = (900, 500))
