# %%
@time using Plots
@time using Statistics
@time using Distributions
# Out:
#  42.974502 seconds (26.06 M allocations: 1.373 GiB, 4.16% gc time)
#   0.259309 seconds (132.40 k allocations: 6.585 MiB)
#   8.108150 seconds (3.96 M allocations: 210.277 MiB, 0.98% gc time)

# %%
function RK4integrate(t::Float64, y::Float64, dt::Float64, f)
    F1 = dt*f(t, y)
    F2 = dt*f(t + dt/2, y + F1/2)
    F3 = dt*f(t + dt/2, y + F2/2)
    F4 = dt*f(t + dt, y + F3)
    
    return y + (F1 + 2*F2 + 2*F3 + F4)/6
end
# Out:
# RK4integrate (generic function with 1 method)

# %%
function forwardEuler(y::Float64, dt::Float64, f)
    return y + dt*f(y)
end
# Out:
# forwardEuler (generic function with 1 method)

# %%
function gaussian(N, mu, sig)
    return rand(Normal(mu, sig), N)
end
# Out:
# gaussian (generic function with 1 method)

# %%
function lorentzian(N, mu, sig)
    return rand(Cauchy(mu, sig), N)
end
# Out:
# lorentzian (generic function with 1 method)

# %%
function kuramotoModel(N, κ, dFunc, nSteps, σ)
    ω = dFunc(N, 0, σ)  #initial frequency distribution
    θ = 2*pi*rand(Float64, (N)) #phase of each oscillator
    ψ = zeros(Float64, (nSteps)) #mean phase
    r = zeros(Float64, (nSteps)) #mean radius
    Δt = 5e-4
    
    for k in 1:nSteps
        θsum = mean(cis.(θ))
        ψ[k], r[k] = angle(θsum), abs(θsum)

        for i in 1:length(θ)
            θ[i] += Δt * (ω[i] + κ*r[k]*sin(ψ[k] - θ[i]))
        end
    end
    
    plot(Δt*collect(1:length(r)), r, lw = 2, ylim = (0,1))
    #return(mean(r[nSteps - 20000, end]))
end
# Out:
# kuramotoModel (generic function with 1 method)

# %%
@time kuramotoModel(2000, 1.5, gaussian, Int(5e4), 1)
# Out:
#   8.105872 seconds (102.33 k allocations: 1.496 GiB, 0.74% gc time)

# %%
k = collect(0:0.25:11)
R = zeros(Float64, length(k))
sig = 2.5*sqrt(pi/2)

@time begin
    for i in 1:length(k)
        R[i] = kuramotoModel(2000, k[i], gaussian, Int(5e4), sig) 
    end
end
# Out:
# 271.223953 seconds (4.50 M allocations: 67.258 GiB, 1.55% gc time)

# %%
scatter(k, R, lw = 2, label = "", legend = :topleft, xlabel = "K", ylabel = "r")
plot(k, R, lw = 2, label = "", color = :blue)

# %%
function kuramotoData(N, κ, dFunc, nSteps, σ)
    ω = dFunc(N, 0, σ)  #initial frequency distribution
    θ = 2*pi*rand(Float64, (N)) #phase of each oscillator
    ψ = zeros(Float64, (nSteps)) #mean phase
    r = zeros(Float64, (nSteps)) #mean radius
    Δt = 5e-4
    
    for k in 1:nSteps
        θsum = mean(cis.(θ))
        ψ[k], r[k] = angle(θsum), abs(θsum)

        for i in 1:length(θ)
            θ[i] += Δt * (ω[i] + κ*r[k]*sin(ψ[k] - θ[i]))
        end
    end
    
    #plot(1:length(r), r, lw = 2, ylim = (0,1))
    return(std(r[nSteps - 20000, end]))
end
# Out:
# kuramotoData (generic function with 1 method)

# %%
N = collect(1:5:100)
err = zeros(Float64, length(N))
sig = 2.5*sqrt(pi/2)
k = 7

@time begin
    for i in 1:length(N)
        err[i] = kuramotoModel(N[i], k, gaussian, Int(5e4), sig) 
    end
end
# Out:
#   3.194381 seconds (1.06 M allocations: 858.369 MiB, 6.67% gc time)

# %%
plot(N, err, lw = 2, label = "", color = :blue)

# %%
0:0.1:100
# Out:
# 0.0:0.1:100.0
